# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 2

# %%
numpyDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigure , benimEksen) = plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,color="#3A95A8")
benimEksen.plot(numpyDizisi2,numpyDizisi1,color="#C96F23")
# Saydamlık katmak için alpha = değerini düşürebiliriz

# %%
(yeniFigure,yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1 , numpyDizisi1 + 2 , color = "blue" , linewidth = 8.0)
yeniEksen.plot(numpyDizisi1 , numpyDizisi1 + 3 , color = "green" , linewidth =6.0)
# linewidth = komutuyla çizginin kalınlığı ayarlanabiliyor

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "purple", linestyle="-.")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 5, color = "black", linestyle="--")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 6, color = "yellow", linestyle=":")

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 7, color = "purple", linestyle="--",marker="o",markerfacecolor="black")

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# ## histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([81, 11, 61, 79, 50, 75, 28, 13, 31, 54, 68, 71, 49, 61, 45, 63, 22,
#        70, 16, 36, 21, 75, 57,  2, 39, 59, 69, 32,  3, 21, 31, 12, 87,  6,
#        55, 48, 15, 46, 68, 42, 60, 93, 42, 83,  0, 46, 90, 13, 59, 62])

# %%
plt.hist(yeniDizi)
# Out:
# (array([4., 6., 3., 5., 6., 5., 8., 5., 5., 3.]),
#  array([ 0. ,  9.3, 18.6, 27.9, 37.2, 46.5, 55.8, 65.1, 74.4, 83.7, 93. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
# standart sapmayla alakalı grafiklerde kullanılır
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25aae9ca8d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25aae9cac00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25aae96e750>],
#  'medians': [<matplotlib.lines.Line2D at 0x25aae9caf90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25aae9fc170>],
#  'means': []}
